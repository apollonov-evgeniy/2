# %% [markdown]
# <a href="https://colab.research.google.com/github/apollonov-evgeniy/2/blob/main/proj5_%D1%81%D0%B1%D0%BE%D1%80%D0%BD%D1%8B%D0%B9_1_%D0%B8%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D0%BE%D0%B2%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D1%80%D1%8B%D0%BD%D0%BA%D0%B0_%D0%BA%D0%BE%D0%BC%D0%BF%D1%8C%D1%8E%D1%82%D0%B5%D1%80%D0%BD%D1%8B%D1%85_%D0%B8%D0%B3%D1%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Евгений, привет!</b>
#
# Меня зовут Евгений Д., и я буду проверять твой проект. Предлагаю общаться на «ты» 😊 Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Ты уже проделал большую работу над проектом, но давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b> Так выделены небольшие замечания. Одна-два таких замечания в проекте допустимы, но если их будет больше - тебе будет необходимо внести исправления. Это как тестовое задание при приеме на работу: очень много мелких ошибок могут стать причиной отказа кандидату.
#
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# _Сборный проект_

# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# ### Описание проекта
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
#
#
# #### Описание данных
# * Name — название игры
# * Platform — платформа
# * Year_of_Release — год выпуска
# * Genre — жанр игры
# * NA_sales — продажи в Северной Америке (миллионы проданных копий)
# * EU_sales — продажи в Европе (миллионы проданных копий)
# * JP_sales — продажи в Японии (миллионы проданных копий)
# * Other_sales — продажи в других странах (миллионы проданных копий)
# * Critic_Score — оценка критиков (максимум 100)
# * User_Score — оценка пользователей (максимум 10)
# * Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.
#
# #### Инструкция по выполнению проекта
#
# _Шаг 1. Откройте файл с данными и изучите общую информацию_
# Путь к файлу: /datasets/games.csv.
#
# _Шаг 2. Подготовьте данные_
# - Замените названия столбцов (приведите к нижнему регистру);
# - Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип  данных и почему;
# - Обработайте пропуски при необходимости:
# - Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# - Опишите причины, которые могли привести к пропускам;
# - Обратите внимание на аббревиатуру 'tbd' в столбцах с рейтингом. Отдельно разберите это значение и опишите, как его обработать;
# - Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# _Шаг 3. Проведите исследовательский анализ данных_
# - Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# - Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# - Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. Не учитывайте в работе данные за предыдущие годы.
# - Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# - Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# - Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# - Соотнесите выводы с продажами игр на других платформах.
# - Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# _Шаг 4. Составьте портрет пользователя каждого региона_
# - Определите для пользователя каждого региона (NA, EU, JP):
# - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# - Самые популярные жанры (топ-5). Поясните разницу.
# - Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# _Шаг 5. Проверьте гипотезы_
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# Задайте самостоятельно пороговое значение alpha.
# - Поясните:
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.
#
# _Шаг 6. Напишите общий вывод_

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здорово, когда есть вступление в сам проект, каждый сможет быстрее разобраться с тем о чем сам проект 👍
#
# </div>я

# %% [markdown]
# ## Шаг 1. Файл с данными и общая информация

# %%
# установим пакет Plotly, при необходимости (некоторые графики выдают ошибки без установки последней версии)
# !pip install cufflinks plotly -U

# %%
import pandas as pd

import matplotlib.pyplot as plt
import math as math
import numpy as np
import datetime
import seaborn as sns

from scipy import stats as st
pd.options.plotting.backend = "plotly" 

import plotly.graph_objs as go
import cufflinks as cf
import plotly.express as px
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
# Задаем некоторые опции библиотеки pandas, которые
# настраивают вывод
pd.set_option('display.max_rows', 20)
pd.set_option('display.width', 80)
# увеличиваем количество выводимых столбцов
#pd.set_option('display.max_columns', 60)
pd.set_option('display.float_format', lambda x: '%.2f' % x)#формат вывода для удобства
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Знакомство с данными

# %%
try:
    games = pd.read_csv("datasets/games.csv")
except:
    try:
        games = pd.read_csv("/datasets/games.csv")
    except:
        games = pd.read_csv("https://code.s3.yandex.net/datasets/games.csv")
finally:
    display(games.head(10))
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii          2006.00        Sports
# 1          Super Mario Bros.      NES          1985.00      Platform
# 2             Mario Kart Wii      Wii          2008.00        Racing
# 3          Wii Sports Resort      Wii          2009.00        Sports
# 4   Pokemon Red/Pokemon Blue       GB          1996.00  Role-Playing
# 5                     Tetris       GB          1989.00        Puzzle
# 6      New Super Mario Bros.       DS          2006.00      Platform
# 7                   Wii Play      Wii          2006.00          Misc
# 8  New Super Mario Bros. Wii      Wii          2009.00      Platform
# 9                  Duck Hunt      NES          1984.00       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45         76.00          8      E
# ...

# %%
games.describe(include = 'all').transpose()
# Out:
#                    count unique                          top  freq    mean  \
# Name               16713  11559  Need for Speed: Most Wanted    12     NaN
# Platform           16715     31                          PS2  2161     NaN
# Year_of_Release 16446.00    NaN                          NaN   NaN 2006.48
# Genre              16713     12                       Action  3369     NaN
# NA_sales        16715.00    NaN                          NaN   NaN    0.26
# EU_sales        16715.00    NaN                          NaN   NaN    0.15
# JP_sales        16715.00    NaN                          NaN   NaN    0.08
# Other_sales     16715.00    NaN                          NaN   NaN    0.05
# Critic_Score     8137.00    NaN                          NaN   NaN   68.97
# User_Score         10014     96                          tbd  2424     NaN
# Rating              9949      8                            E  3990     NaN
#
#                   std     min     25%     50%     75%     max
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Предстоит предобработка данных. Много пропусков, необходимо посмотреть внимательно на типы данных

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Достаточно детально изучили наши первичные данные, давай теперь их обработаем.
# </div>

# %% [markdown]
# ## Шаг 2. Подготовка данных

# %% [markdown]
# ###### Приведение название столбцов к нижнему регистру

# %%
games.columns= games.columns.str.lower()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Отличный способ заменить регистр в наших данных 👍
# </div>

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16713 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null float64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         10014 non-null object
# rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ###### Изучение пропусков

# %%
def view_nan(df1): 
    plt.figure(figsize=(12,7))
    # определяем цвета 
    # желтый - пропущенные данные, синий - не пропущенные
    colours = ['#000099', '#ffff00'] 
    sns.heatmap(df1[list(df1)].isnull(), cmap=sns.color_palette(colours))
    # выведем проценты пропусков 
    for col in df1.columns:
        pct_missing = np.mean(df1[col].isnull())
        pct_missing_sum = df1[col].isnull().sum()
        if pct_missing_sum > 0:
            print(f'{pct_missing_sum} пропуска в {col} -  составляют -{pct_missing:.2%}')

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Классная функция 👍
# </div>

# %%
# визуализируем пропуски, на графике отсортируем значения по году релиза, 
# выведем количество и проценты пропусков
view_nan(games.sort_values('year_of_release'))
# Out:
# 2 пропуска в name -  составляют -0.01%
# 269 пропуска в year_of_release -  составляют -1.61%
# 2 пропуска в genre -  составляют -0.01%
# 8578 пропуска в critic_score -  составляют -51.32%
# 6701 пропуска в user_score -  составляют -40.09%
# 6766 пропуска в rating -  составляют -40.48%

# %% [markdown]
# Практически половина данных отсутствует по столбцам critic_score, rating и user_score. По этим столбцам пропуски часто соответствуют друг другу. Как видно, до определенного времени данные отсутствовали почти полностью. например:

# %%
print('количество строчек с непропущенными данными до 2000 года')
print(len(games[games.user_score.notnull()&  (games.year_of_release < 2000)]))
print('пропуски')
print(len(games[games.user_score.isnull()&  (games.year_of_release < 2000)]))
# Out:
# количество строчек с непропущенными данными до 2000 года
# 101
# пропуски
# 1875

# %% [markdown]
# После этого, количество пропусков падает. Можно предположить следующее:
#
# critic_score - оценка критиков, user_score - оценка игроков (не обязательная характеристика игры) - до определенного времени  данные не аккумулировались, или они не представлены в современных системах сбора рейтинга. В последующем, для части игр рейтинги могли не подсчитываться в данной системе агрегации например сайта Metacritic (рейтинги игр, вышедших на рынки других стран и т.п.)
# Здесь стоит рассмотреть рейтинг пользователей со значением *tbd*

# %%
# Исследуем значение `tbd` в 'user_score'
print(len(games[games['user_score'] == 'tbd']))
# Out:
# 2424

# %% [markdown]
# 2424 строк с таким значением.
#
# tbd от To Be Determined. Пишется тогда, когда игра имеет недостаточное количество отзывов, по всей видимости данные взяты с сайта Metacritic. Это может быть если игра малопопулярная, основная аудитория игры не относится к аудитории Metacritic.
#
# Фактически 'tbd' - NaN, заменим tdb на NaN
#
# . Было бы неправильно заполнить рейтинг игры средним или медианой, даже если бы мы их считали внутри для каждого жанра отдельно.
# заменим на -1 (как признак);
#
# rating - рейтинг от ESRB -основана в 1994 году. Рейтинга до этого нет. Тоже не является обязательным параметром. Заявляется добровольно, в основном для выхода на рынок США и Канады. (т.е. все так же, как и оценки) Невозможно дать рейтинг игре, посчитав его как среднее рейтингов игр того же жанра. Поставим рейтинг "No";
#
# Столбец year_of_release (год выпуска игры) имеет 1,6% пропусков. Средними/медианами эти пропуски не заполнить. Заменим на не реальное значение - признак 1900. (В последствии дальнейшего изучения, было принято решение заменить медианой с группировкой по платформам)
#
# Пропуски в столбцах name и genry в одинаковых строках(всего 2) - удалим

# %% [markdown]
# ###### Обработка пропусков и значения 'tbd', Изменение типов данных

# %%
# Преобразуем неявные пропуски `tbd` в NaN
games.loc[games.user_score == 'tbd' , 'user_score'] = np.NaN

# %%
# Заменим значения как описано ранее и поменяем типы данных
# user_score из строкового (после замены *tbd*) в float
# critic_score float --> int
games.user_score = games.user_score.fillna(-1).astype('float')
games.critic_score = games.critic_score.fillna(-1).astype('int')
games.rating = games.rating.fillna('No')

# %%
# После изучения "жизни" платформ, было принято решение заменить пропуски в годах
# на медиану по платформам. Замена на признак (1900 дальше не нужна. в коде осталась)
year_of_release_median =(
    games
    .groupby(['platform'])
    .agg({'year_of_release': 'median'})['year_of_release']
    .round()
    .to_dict()
)

(games
    .year_of_release
    .fillna(games.loc[games.year_of_release.isnull(),'platform']
                  .map(year_of_release_median), inplace=True))


# год релиза NaN на 1900, 
#float--> int, т.к. год целое число
games.year_of_release = games.year_of_release.fillna(1900)
games.year_of_release = games.year_of_release.astype('int')

# %%
# удаляем строчки, где name и genry - NaN
games=(games[~games.name.isnull()])
games=(games[~games.genre.isnull()])

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Кстати данные операции фильтрации мы можем выполнять с помощью метода `loc`
#
# </div>

# %%
# проставим строчные буквы в строчках
games.name = games.name.str.lower()
games.platform = games.platform.str.lower()
games.genre = games.genre.str.lower()
games.rating = games.rating.str.lower()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здесь можно было бы применить цикл `for`.
#
# Для себя можно определить некий фильтр по которому мы будем определять когда нам удобно использовать цикл или внедрнить функцию – когда наши действия повторяются более 2–х раз.
#
# </div>

# %%
# Поиск дупликатов
games.duplicated().sum()
# Out:
# 0

# %%
games.isnull().sum()
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %% [markdown]
# ###### Количество продаж во всех регионах и запись в отдельный столбец

# %%
games['total_sales'] =(
    games.na_sales + games.eu_sales 
    + games.jp_sales + games.other_sales
)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Кстати мы можем применить метод `sum(axis=1)` к суммируемым столбцам.
# </div>

# %%
games.describe()
# Out:
#        year_of_release  na_sales  eu_sales  jp_sales  other_sales  \
# count         16713.00  16713.00  16713.00  16713.00     16713.00
# mean           2006.47      0.26      0.15      0.08         0.05
# std               5.90      0.81      0.50      0.31         0.19
# min            1980.00      0.00      0.00      0.00         0.00
# 25%            2003.00      0.00      0.00      0.00         0.00
# 50%            2007.00      0.08      0.02      0.00         0.01
# 75%            2010.00      0.24      0.11      0.04         0.03
# max            2016.00     41.36     28.96     10.22        10.57
#
#        critic_score  user_score  total_sales
# count      16713.00    16713.00     16713.00
# mean          33.06        2.69         0.53
# std           36.30        4.17         1.55
# min           -1.00       -1.00         0.00
# 25%           -1.00       -1.00         0.06
# 50%           -1.00       -1.00         0.17
# 75%           70.00        7.30         0.47
# ...

# %% [markdown]
# ## Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# ###### Выпуск игр по годам

# %%
(
games[games.year_of_release != 1900]['year_of_release']
    .iplot(kind='hist', xTitle='Год релиза', 
    yTitle='Количество', title='Количество выпускаемых игр по годам')
)
# Out:
# <div>                            <div id="4d635309-5024-4e26-8ea8-7bc629609e4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# До 1994 год игр выпускалось мало, в основном для PC. Начало увеличиваться с запускрм других платформ. Резкий скачок по количеству игр, выпущенных в год, произошел в 2002 году. Пик - 2008-2009 года. После этого началось снижение, связанное с развитием мобильных устройств, так и усложнением и удорожанием производства самих игр для данных платформ.
#
# Объем игрового рынка не был таким массовым до выхода консолей типа Sony PlayStation и широкого распространения персональных компьютеров. Данные до середины девяностых не интересны для текущего рассмотрения.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здорово, когда график и его оси подписаны 😊👍
#
# Так быстрее понять о чем идёт речь на самом графике.
#
# ---
#
# Классно, что уже используем `plotly` 👍👍👍
#
# </div>

# %% [markdown]
# ###### Изменение продаж по платформам. Платформы с наибольшими суммарными продажами. Характерный срок жизни платформ

# %%
(
games.pivot_table(index='platform', values='total_sales', aggfunc='sum',fill_value=0)
            .sort_values('total_sales', ascending=False)
            .iplot(kind='bar', xTitle='Платформа', yTitle='Сумма продаж млн копий', title='Продажи по платформам за весь период')
    )
# Out:
# <div>                            <div id="ca134bc6-5527-4137-9f92-a79f2b33e071" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Лидером является платформа PS2.
# Далее идут Xbox360, PS3 и Wii.

# %% [markdown]
# Выберем платформы с наибольшими глобальными продажами, например, первые 10 из списка выше и построим распределение по годам.

# %%
top10 =(
    list(games.pivot_table(index='platform', 
    values='total_sales', aggfunc='sum')
    .sort_values('total_sales', ascending=False)
    .head(10)
    .index)
)
print (f'топ 10 платформ по продажам {top10}')

(
    games[(games.year_of_release != 1900) & (games.platform.isin(top10))]
    .pivot_table(index='year_of_release', 
    values='total_sales',columns = 'platform', 
    aggfunc='sum')
    .iplot(kind='line',yaxis_title='продажи млн копий', title='Продажи по платформам топ 10 за весь период')
)
# Out:
# топ 10 платформ по продажам ['ps2', 'x360', 'ps3', 'wii', 'ds', 'ps', 'gba', 'ps4', 'psp', 'pc']
# <div>                            <div id="25fcadb4-40ad-4fad-a4a2-cca641f95f25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
#  Посмотрим на характерный срок жизни платформы из ТОП 10 по продажам.
#
# PS - с 1994 года до 2003, почти 10 лет;
# PS2 - с 2000 до 2011 года - 11 лет;
# PS3 - с 2006 по 2016, 10 лет, сильное падение в 2013 году;
# DS - с 2004 года до 2013 год - 8 активных лет жизни;
# Wii - с 2006 по 2016 уже почти изжила себя -  10 лет.
# Таким образом, в среднем платформа живет 10 лет.
#
#  Примерно за 10 лет появляются новые и исчезают старые платформы. Таким образом, мы еще раз убедились, что данные за все периоды нам не понадобятся – достаточно определить актуальный период в 10 лет и смотреть на игры на современных платформах.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# Обрати внимание, что график не совсем читабелен, потому что включает в себя много линий.
#
# Рекомендовал бы посмотреть каждую платформу на отдельном графике или использовать метод `subplots`.
#
# </div>

# %% [markdown]
# ######  Актуальный период
# определите самостоятельно в результате исследования предыдущих вопросов.
# Не учитывайте в работе данные за предыдущие годы.

# %% [markdown]
# Актуальным периодом  будем считать  период с 2005 по 2016 год:
# ЗАМЕТИМ, ЧТО ДАННЫЕ за 2016 год МОГУТ БЫТЬ не полными.
# Видимое ПАДЕНИЕ ПРОДАЖ в 2016 году может быть вызвано неполнотой данных и требует дополнительного изучения. На распределение в ТОП позициях это не влиляет.
#
# в этом периоде представлены данные по абсолютно всем самым популярным консолям.
# Предыдущие года отбросим.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Согласен.
#
# В том числе мы могли посчитать это – вычесть из максимальной даты минимальную по каждой платформе и затем усреднить получившиеся значения.
#
# </div>

# %% [markdown]
# ###### Лидеры продаж. Потенциально прибыльные платформы
#
# Построим ещё один график, отображающий динамику продаж по уже актуальным годам и ответим на вопрос:
# Какие платформы лидируют по продажам, растут или падают?
#
# На основании полученных данных выберем несколько потенциально прибыльных платформ.

# %% [markdown]
# ДАЛЕЕ БУДЕМ РАБОТАТЬ С ДАННЫМИ АКТУАЛЬНОГО ПЕРИОДА

# %%
# Выведем из дальнейшего рассмотрения не актуальные данные

actual_years = (games['year_of_release'] >= 2006) & (games['year_of_release'] <= 2016)
games = games.loc[actual_years]
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10494 entries, 0 to 16714
# Data columns (total 12 columns):
# name               10494 non-null object
# platform           10494 non-null object
# year_of_release    10494 non-null int64
# genre              10494 non-null object
# na_sales           10494 non-null float64
# eu_sales           10494 non-null float64
# jp_sales           10494 non-null float64
# other_sales        10494 non-null float64
# critic_score       10494 non-null int64
# user_score         10494 non-null float64
# rating             10494 non-null object
# total_sales        10494 non-null float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 1.0+ MB

# %%
(
games.pivot_table(index='platform', values='total_sales',
                  aggfunc='sum',fill_value=0)
            .sort_values('total_sales', ascending=False)
            .iplot(kind='bar', xTitle='Платформа', 
            yTitle='Продано млн копий',
            title='Продажи по платформам за актуальный период с 2006 года')
    )
# Out:
# <div>                            <div id="5d0096d6-b0ac-4ca6-bf0f-dc90c8c7e1fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
(
    games
    .pivot_table(index='year_of_release', 
    values='total_sales',columns = 'platform', 
    aggfunc='sum')
    .iplot(kind='line',yaxis_title='Продано млн копий', 
    title='Продажи по платформам с разбивкой по годам')
)
# Out:
# <div>                            <div id="fabb85d8-f51d-4621-ab0c-52f4f0d4b341" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#Построим график по количеству игр, выпускаемых по платформам 
# для более точного нахождения живых платформ
(
    games
    .pivot_table(index='year_of_release', 
    values='total_sales',columns = 'platform', 
    aggfunc='count')
    .iplot(kind='line',yaxis_title='количество релизов',
    title='Количество игр выпускаемых по платформам')
)
# Out:
# <div>                            <div id="9b97f813-ea30-4128-bd9b-795efb53cc5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Используя модуль plot.ly можно детально разглядывать графики, скрывать не нужные.
#
# По результатам анализа видим, что несмотря на лидирующие продажи за актуальный период, эра большинства платформ подходит к концу и продажи значительно падают. можно выделить несколько переспективных групп (данные за 2016 рассматривать не будем, как не полные).
#
# 1. платформы нового поколения: ps4, xone - лидеры по росту продаж и росту количества новых релизов
# 2. платформы постарее (падающие в продажах (после выхода ps4, xone, но не изжившие свой цикл) на которые стоит обратить внимание, 3ds, psv и wiiu
# psv - уверенно выпускает новые релизы.
# 3. и отдельная платформа PC, которая демонстрирует постоянство год от года, как по продажам, так и по выпуску новых релизов
#
#
# Объем продаж компьютерных игр с каждым годом все меньше.
#
# Рассмотрим детальнее платформы от Sony и Microsoft

# %% [markdown]
# ###### «Ящик с усами» по глобальным продажам игр в разбивке по платформам.

# %%
fig = px.box(games.total_sales)
fig.show()
# Out:
# <div>                            <div id="421e57ae-9aa3-4bb8-9566-d417ab6d1002" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("421e57ae-9aa3-4bb8-9566-d417ab6d1002")) {                    Plotly.newPlot(                        "421e57ae-9aa3-4bb8-9566-d417ab6d1002",                        [{"alignmentgroup": "True", "hovertemplate": "variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["total_sales", "total_sales", "total_sales", "total_sales", "total_sales", "total_sales", "total_sales", "total_sales", "total_sales", "total_sales", "total_sales", "total_sales", "total_sales", "total_sales", "tota
# ...

# %%
top_platforms = ['ps4', 'xone', '3ds', 'pc', 'psv', 'wiiu']
games_top= games[games.platform.isin(top_platforms)]
# print(games_top.head())
fig = go.Figure()
fig.add_trace(go.Box
                (x=games_top.platform, 
                y=games_top.total_sales))
fig.update_layout(title= 'Глобальные продажи по платформам за актуальный период', xaxis_title='платформы',
                      yaxis_title='продано млн копий',boxmode='group')
fig.show()
# Out:
# <div>                            <div id="513c4368-7155-4f14-8f99-2c4ec762886b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("513c4368-7155-4f14-8f99-2c4ec762886b")) {                    Plotly.newPlot(                        "513c4368-7155-4f14-8f99-2c4ec762886b",                        [{"type": "box", "x": ["ps4", "3ds", "3ds", "ps4", "3ds", "3ds", "3ds", "3ds", "ps4", "pc", "ps4", "ps4", "ps4", "3ds", "xone", "ps4", "3ds", "wiiu", "ps4", "ps4", "xone", "ps4", "xone", "3ds", "wiiu", "pc", "wiiu", "pc", "ps4", "ps4", "3ds", "xone", "ps4", "wiiu", "wiiu", "3ds", "wiiu", "ps4", "xone", "pc", "ps4", "ps4", "ps4", "ps4", "ps4", "ps4", "3ds", "pc", "ps4", "3ds", "ps4", "ps4", "xone", "ps4", "xone", "3ds", "ps4", "ps4", "xone", "3ds", "3ds", "xone", "
# ...

# %% [markdown]
# Среднее по всем продажам в районе 0,15 млн. копий. Основные продажи до 0,95 млн. копий. Выше этого аномалии - сверх удачные продажи игр, могут превышать среднее в десятки раз
# Медиана по топовым платформам варьируется от 0,2 до 0,22 млн проданных игр . Видно что средние продажи PS4 и Xone идут на одном уровне. Продажи PS4 имеют больший уровень выбросов - успешных продаж.
# Продажи других платфом подтверждают наше разбиение на групы. Средние продажи меньше, успешные выбросы начинаются с более низкого уровня.
# 3ds и Wiiu часто имеет "выстреливающие" игры? и в среднем по продажам ниже лидирующих платформ
# PC и PSV находятся внизу продаж, но демонстрируют стабильность по продажам.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Обртати внимание, что наши графики повторяются.
#
# Это говорит о том, что мы можем создать функцию для оптимизации нашего кода.
#
# </div>

# %% [markdown]
# ######  Диаграмма рассеяния и  корреляция между отзывами и продажами.

# %% [markdown]
# За образец возьмем PS4 - , по ней много данных, при этом  на конец 2016 года она является одной из самых популярных игровых платформ

# %%
games_ps4 = games[(games['platform'] == 'ps4')].copy()
games_ps4[games_ps4['critic_score'] >= 0].plot(kind='scatter',
                            x='critic_score', y='total_sales',
                            title = 'с рейтингами критиков')
# Out:
# <div>                            <div id="7572fa51-d1ce-498f-8888-bcb0966b6b7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7572fa51-d1ce-498f-8888-bcb0966b6b7e")) {                    Plotly.newPlot(                        "7572fa51-d1ce-498f-8888-bcb0966b6b7e",                        [{"hovertemplate": "critic_score=%{x}<br>total_sales=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [97, 82, 83, 85, 87, 82, 76, 93, 86, 77, 88, 80, 85, 92, 70, 87, 87, 78, 80, 85, 93, 76, 83, 87, 84, 83, 80, 83, 73, 92, 83, 76, 73, 81, 90, 73, 74, 71, 89, 80, 86, 79, 88, 73, 68, 75, 82, 63, 54, 61, 71, 79, 89, 83, 79, 85, 7
# ...

# %% [markdown]
# С увеличением среднего рейтинга критиков увеличивается и средний уровень выручки с продажи игр.

# %%
games_ps4[games_ps4['user_score'] >= 0].plot(kind='scatter',
                                    x='user_score',
                                    y='total_sales', 
                                    title = 'с рейтингами пользователей')
# Out:
# <div>                            <div id="0651eeda-2b7c-4f1a-8ff8-268f672a5d84" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0651eeda-2b7c-4f1a-8ff8-268f672a5d84")) {                    Plotly.newPlot(                        "0651eeda-2b7c-4f1a-8ff8-268f672a5d84",                        [{"hovertemplate": "user_score=%{x}<br>total_sales=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [8.3, 4.3, 5.7, 5.0, 6.5, 5.7, 6.1, 7.9, 8.1, 3.4, 8.4, 6.3, 7.7, 9.2, 4.9, 7.6, 6.7, 3.7, 7.0, 6.9, 8.2, 6.8, 5.9, 6.3, 8.1, 7.8, 7.9, 7.7, 6.8, 8.6, 7.0, 6.3, 7.3, 6.1, 6.1, 5.0, 7.9, 6.1, 7.4, 6.2, 6.0, 7.1, 6.7, 6.5, 5.1, 7.
# ...

# %% [markdown]
# Точно такая же картина, правда так называемых выбросов больше - когда рейтинг пользователей не велик, но тем не менее игра собирает большие деньги.

# %%
features = ['user_score', 'critic_score', 'total_sales']
#ps4[features].corr()

sns.heatmap(games_ps4[(games_ps4['user_score'] >= 0) & (games_ps4['critic_score'] >= 0)][features]
            .corr(), annot=True, cmap="Greens", fmt='.2f', annot_kws={'size':16})

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Класс, ещё и тепловую карту применили 😊👍
# </div>

# %% [markdown]
#  Выводы:
#
# Корреляция между пользователей и продажами очень слабая, взаимосвязи нет;
# Взаимосвязь между отзывами критиков и продажами существует, однако не слишком большая; Корреляция слабая. Коррелируют положительно. Следовательно можно интерпретировать следующим образом:
# Взаимосязь между отзывами критиков и отзывами пользователей существует, чуть большая чем между отзывами критиков и продажами  .
# Корреляция не говорит о причинно-следственной связи. И хотя по диаграммам рассеяния видим, что чем выше оценки критиков, тем выше продажи игр, мы не можем утверждать, что высокие оценки критиков приводят к высоким продажам игр, а при покупке игры пользователи больше доверяют критикам.

# %% [markdown]
# ######  Выводы по продажам игр на других платформах

# %%
games_top =games_top[(games_top['user_score'] >= 0) & (games_top['critic_score'])]
top_platforms = ['ps4', 'xone', '3ds', 'pc', 'psv', 'wiiu']
corr_top_platforms=[]
for platform_t in top_platforms:
    corr_top_platforms.append(games_top.query('platform ==@platform_t')[features].corr().total_sales)    
df1=pd.DataFrame(corr_top_platforms)
df1.index=top_platforms
display('Корреляция по платформам',df1)
# Out:
# 'Корреляция по платформам'
#       user_score  critic_score  total_sales
# ps4        -0.01          0.37         1.00
# xone        0.05          0.30         1.00
# 3ds         0.18          0.23         1.00
# pc          0.07          0.21         1.00
# psv        -0.08          0.21         1.00
# wiiu        0.42          0.36         1.00

# %% [markdown]
# Данные по корреляции между выручкой и оценкой критиков по платформам PS4, Xone, wiiu похожи между собой и выше чем у 3ds, ps и psv, уровень взаимосвязи выше.
# В корреляции пользователей выделяются Wiiu и 3DS, по которым видна зависимость от рейтинга пользователей, в отличии от других платформ - где нет такой зависимости.

# %% [markdown]
#  ###### Распределение игр по жанрам.

# %%
(games
    .pivot_table(index='genre', values='name', aggfunc = 'count')
    .sort_values('name', ascending=False)
    .iplot(kind='bar', y='name', yaxis_title='количество релизов',
    title='Количество релизов по жанрам за актуальный период')
    )
(games
    .pivot_table(index='genre', values='total_sales', aggfunc = 'sum')
    .sort_values('total_sales', ascending=False)
    .iplot(kind='bar', y='total_sales', yaxis_title='млн копий',
    title='Выручка от продаж по жанрам за актуальный период')
    )
# Out:
# <div>                            <div id="1193af21-86e4-42f3-9ccd-fb2d0d43b1c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Больше всего выпускается игр жанра Action. За ними идут игры спортивного жанра. Игр жанра "Спорт" заметно меньше на рынке (половина от Action), выручка от продаж у них не на много ниже.
#
# Топ по количеству продаж и топ по сумме выручки.
#
#
# Количество релизов:
#
# Action
# Спортивный жанр
# Игры "смешанного" жанра - Miscellaneous
# Внизу списка игры, которые требуют усидчивости: strategy, puzzle
#
#
# Сумма выручки:
#
# Action
# Спортивный жанр
# Шутеры
# Внизу списка также: strategy, puzzle
#
# При этом производство игр в жанрах action, shooter и т.д. обходится сильно дороже, чем puzzle.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# А если мы посмотрим на средние значения продаж, какие выводы мы сможем сделать ?
#
# </div>

# %% [markdown]
# ## Шаг 4. Составьте портрет пользователя каждого региона

# %% [markdown]
# ###### Определение самых популярных платформ в заданных регионах

# %%
#выводим только ТОП 5 по каждому региону. Остальные не выводим
# переключая вывод в графике, видим отсортированные значения
pivot_na =(games
           .pivot_table('na_sales',index='platform',aggfunc='sum')
            .sort_values(by='na_sales', ascending=False).head(5)
          )
pivot_eu =(games
           .pivot_table('eu_sales',index='platform',aggfunc='sum')
           .sort_values(by='eu_sales', ascending=False).head(5)
          )
pivot_jp =(games
           .pivot_table('jp_sales',index='platform',aggfunc='sum')
           .sort_values(by='jp_sales', ascending=False).head(5)
          )
fig = go.Figure(data=[
    go.Bar(name='na_sales', x=pivot_na.index, y=pivot_na.na_sales),
    go.Bar(name='eu_sales', x=pivot_eu.index, y=pivot_eu.eu_sales),
    go.Bar(name='jp_sales', x=pivot_jp.index, y=pivot_jp.jp_sales)
])
fig.update_layout(title = 'ТОП 5 продаж  по платформам для регионов за актуальный период', xaxis_title='платформы', barmode='group')
fig.show()
# Out:
# <div>                            <div id="9c2cfd89-b0c8-4cc7-a0da-09bf429352c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c2cfd89-b0c8-4cc7-a0da-09bf429352c5")) {                    Plotly.newPlot(                        "9c2cfd89-b0c8-4cc7-a0da-09bf429352c5",                        [{"name": "na_sales", "type": "bar", "x": ["x360", "wii", "ps3", "ds", "ps2"], "y": [595.5699999999995, 496.8999999999991, 393.48999999999995, 326.07999999999777, 114.89000000000006]}, {"name": "eu_sales", "type": "bar", "x": ["ps3", "x360", "wii", "ds", "ps4"], "y": [330.2899999999974, 270.32999999999686, 262.2099999999984, 143.4699999999997, 141.09000000000032]}, {"name": "jp_sales", "type": "bar", "x": ["ds", "3ds", "ps3", "psp", "wii"], "y": [142.0400000000005
# ...

# %% [markdown]
# В Северной Америке имеют популярность платформы прошлого поколения X360 и Wii. Немного отстает PS3. Топ-4 и топ-5 - DS и PS2 соответственно.
#
# В Европе  впереди PS3, обгоняя X360 и Wii. В конце списка DS, а PS4 потеснила PS2
#
# В Японии лидер - DS. За ним  3DS и PS3. Далее  PSP и Wii.
#
# Видно, ТОП продаж игр меняется от региона

# %% [markdown]
#  ###### Определение самых популярных жанров в заданных регионах

# %%
#выводим только ТОП 5 по каждому региону. Остальные не выводим
pivot_na =(games
           .pivot_table('na_sales',index='genre',aggfunc='sum')
            .sort_values(by='na_sales', ascending=False).head(5)
          )
pivot_eu =(games
           .pivot_table('eu_sales',index='genre',aggfunc='sum')
           .sort_values(by='eu_sales', ascending=False).head(5)
          )
pivot_jp =(games
           .pivot_table('jp_sales',index='genre',aggfunc='sum')
           .sort_values(by='jp_sales', ascending=False).head(5)
          )
fig = go.Figure(data=[
    go.Bar(name='na_sales', x=pivot_na.index, y=pivot_na.na_sales),
    go.Bar(name='eu_sales', x=pivot_eu.index, y=pivot_eu.eu_sales),
    go.Bar(name='jp_sales', x=pivot_jp.index, y=pivot_jp.jp_sales)
])
fig.update_layout(title = 'ТОП 5 продаж по жанрам для регионов за актуальный период', 
                  xaxis_title='жанры', barmode='group')
fig.show()
# Out:
# <div>                            <div id="7e1a4e77-fd59-4b93-ace0-1fbd3165c123" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e1a4e77-fd59-4b93-ace0-1fbd3165c123")) {                    Plotly.newPlot(                        "7e1a4e77-fd59-4b93-ace0-1fbd3165c123",                        [{"name": "na_sales", "type": "bar", "x": ["action", "sports", "shooter", "misc", "role-playing"], "y": [540.0799999999961, 400.75999999999806, 376.0799999999993, 290.40999999999923, 200.0100000000004]}, {"name": "eu_sales", "type": "bar", "x": ["action", "sports", "shooter", "misc", "racing"], "y": [356.9799999999927, 252.6900000000002, 241.09, 148.28000000000029, 114.4800000000003]}, {"name": "jp_sales", "type": "bar", "x": ["role-playing", "action", "misc", "sp
# ...

# %% [markdown]
# Вкусы в Северной Америке и Европе схожи: и там, и там живут фанаты экшнов, спортивных игр, шутеров и смешанного жанра . В Северной Америке больше играют в ролевые игры, в Европе же чаще выбирают гонки.
#
#
# В Японии вкус совершенно иной - на первом месте ролевые игры, причем с большим отрывом. Далее экшны, смешаного жанра, спортивные игры и в конце платформеры.

# %% [markdown]
# ###### Влияние рейтинга ESRB на продажи в отдельном регионе

# %%
#выводим ТОП 5 по рейтингу. Рейтиг No - Пропущенные значения 
pivot_na =(games
           .pivot_table('na_sales',index='rating',aggfunc='sum')
            .sort_values(by='na_sales', ascending=False).head()
          )
pivot_eu =(games
           .pivot_table('eu_sales',index='rating',aggfunc='sum')
           .sort_values(by='eu_sales', ascending=False).head()
          )
pivot_jp =(games
           .pivot_table('jp_sales',index='rating',aggfunc='sum')
           .sort_values(by='jp_sales', ascending=False).head()
          )
fig = go.Figure(data=[
    go.Bar(name='na_sales', x=pivot_na.index, y=pivot_na.na_sales),
    go.Bar(name='eu_sales', x=pivot_eu.index, y=pivot_eu.eu_sales),
    go.Bar(name='jp_sales', x=pivot_jp.index, y=pivot_jp.jp_sales)
])
fig.update_layout(title = 'ТОП 5 продаж по жанрам для регионов за актуальный период', 
                  xaxis_title='жанры', barmode='group')
fig.show()
# Out:
# <div>                            <div id="76021d42-84f0-4531-8031-b7c166707fa4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76021d42-84f0-4531-8031-b7c166707fa4")) {                    Plotly.newPlot(                        "76021d42-84f0-4531-8031-b7c166707fa4",                        [{"name": "na_sales", "type": "bar", "x": ["e", "m", "t", "e10+", "no"], "y": [802.1499999999919, 577.6399999999968, 432.9999999999979, 323.0899999999981, 275.7199999999974]}, {"name": "eu_sales", "type": "bar", "x": ["e", "m", "t", "no", "e10+"], "y": [461.6199999999924, 401.90999999999633, 239.1900000000008, 228.01000000000042, 178.46999999999994]}, {"name": "jp_sales", "type": "bar", "x": ["no", "e", "t", "m", "e10+"], "y": [279.2899999999842, 120.4600000000003
# ...

# %% [markdown]
# В Северной Америке и в Европе картина практически одинаковая. Большая часть выручки получено с игр с рейтингом «E» («Everyone») — «Для всех», далее «M» («Mature») — «Для взрослых»,  «T» («Teen») — «Подросткам», «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»
# Отдельно нужно рассматривать продажи для игр с отсутствующим рейтингом. Напомним, что рейтинг ESRB - дело добровольное.
#
# В Японии опять не так. Первое место с рейтигом No,  далее «E» («Everyone») — «Для всех»,  «T» («Teen») — «Подросткам», «M» («Mature») — «Для взрослых»,  , «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»
#
# Рейтинг "No" для Японии показывает популярность игр созданных для японского рынка, и не отданых для определение рейтинга в ESRB. Рейтинг для подросков выше, чем рейтинг для взрослых

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Достаточно детально проанализировали наши данные и изучили портреты пользователей.
#
#
# </div>

# %% [markdown]
# ## Шаг 5.Проверка гипотез

# %% [markdown]
# Будем использовать t-критерий Стьюдента, так как сравниваемые выборки независимы между собой.Определим пороговое значение alpha = 0.05

# %% [markdown]
# ###### Гипотезы 1:
# H0: средний пользовательский рейтинг платформ Xbox One и PC одинаковый
# H1: средний пользовательский рейтинг платформ Xbox One и PC различается

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Гипотезы сформулированы верно.
#
#
# **Best practies:**
#
# Перед проверкой гипотезы рекомендую проверить дисперсии выборок, чтобы корректно определить атрибут `equal_val` в Т–тесте.
#
# В том числе стоит визуализировать распределение каждой выборки.
#
# </div>

# %%
# сравнение стат парамеров
def compare_stat(df1, df2, column_df):
    df1_mean=df1[column_df].mean()
    df2_mean=df2[column_df].mean()
    # выборочная совокупность ddof=1
    df1_variance =np.var(df1[column_df], ddof=1)
    df2_variance =np.var(df2[column_df], ddof=1)
    
    df1_standard= np.std(df1[column_df], ddof=1)
    df2_standard= np.std(df2[column_df], ddof=1)
    
    print(f'Smart по ({column_df}) Среднее - {df1_mean:.2f}, \
        Дисперсия - {df1_variance:.2f}, Стандартное отклонение - {df1_standard:.2f}')
    print(f'Ultra по ({column_df}) Среднее - {df2_mean:.2f}, \
        Дисперсия - {df2_variance:.2f}, Стандартное отклонение - {df2_standard:.2f}')

# %%
# вспоминаем, что в столбцах пользовательского рейтинга замененины NaN на -1


alpha = 0.05 # критический уровень статистической значимости, 
#если p-value окажется меньше его - отвергнем гипотезу
xone = games.query('platform == "xone" and user_score  >= 0').user_score
pc = games.query('platform == "pc" and user_score  >= 0').user_score

# %%
df1_mean=xone.mean()
df2_mean=pc.mean()
    # выборочная совокупность ddof=1
df1_variance =np.var(xone, ddof=1)
df2_variance =np.var(pc, ddof=1)
    
df1_standard= np.std(xone, ddof=1)
df2_standard= np.std(pc, ddof=1)
    
print(f'Для платформы XONE пользовательские рейтинги')
print(f'Среднее - {df1_mean:.2f}, \
 Дисперсия - {df1_variance:.2f}, Стандартное отклонение - {df1_standard:.2f}')
print(f'Для платформы PC пользовательские рейтинги')
print(f'Среднее - {df2_mean:.2f}, \
 Дисперсия - {df2_variance:.2f}, Стандартное отклонение - {df2_standard:.2f}')
# Out:
# Для платформы XONE пользовательские рейтинги
# Среднее - 6.52,  Дисперсия - 1.91, Стандартное отклонение - 1.38
# Для платформы PC пользовательские рейтинги
# Среднее - 6.83,  Дисперсия - 2.31, Стандартное отклонение - 1.52

# %% [markdown]
# Выдвинем предположение, что полученные результаты о различии пользовательского рейтинга для двух платформ получены случайным образом и на самом деле рейтинги в генеральной совокупности  не отличаются
# (H0: средний пользовательский рейтинг платформ Xbox One и PC одинаковый)

# %%
result=(
    st
    .ttest_ind(xone, pc)
)
print(f'p-значение: {result.pvalue}')

if result.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.013544530124922337
# Отвергаем нулевую гипотезу

# %% [markdown]
# Верно следующее утверждение: средние пользовательские рейтинги платформ Xbox One и PC отличаются между собой
# Вероятность получения таких различий случайным образом  мала. Полученные отличия рейтингов по платформам считаем статистически значимыми.

# %% [markdown]
# ###### Гипотезы 2:
# H0: средний пользовательский рейтинг жанров Action и Sport одинаковый
# H1: средний пользовательский рейтинг жанров Action и Sport различается

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Гипотезы сформулированы верно.
#
# </div>

# %%
# вспоминаем, что в столбцах пользовательского рейтинга замененины NaN на -1


alpha = 0.05 # критический уровень статистической значимости, 
#если p-value окажется меньше его - отвергнем гипотезу
action = games.query('genre == "action" and user_score  >= 0').user_score
sport = games.query('genre == "sports" and user_score  >= 0').user_score

# %%
result=(
    st
    .ttest_ind(action, sport)
)
print(f'p-значение: {result.pvalue}')

if result.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 2.820160145225482e-11
# Отвергаем нулевую гипотезу

# %% [markdown]
# Средние пользовательские рейтинги различаются, и практически нулевая вероятность говорит о том, что случайно получить такое отличие в значениях практически не получится.
#
# Гипотеза Средние пользовательские рейтинги жанров Action и Sports разные подтвердилась

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Платформы появляются и умирают в течение 10 лет.
#
# Наиболее популярные на данный момент платформы  ps4, xone - лидеры по росту продаж и росту количества новых релизов
#
# Рекомендуется обратить внимание на группу платформ, которые не имеют такого роста продаж, но могут дать стабильность по спросу:
#
# платформы постарее (падающие в продажах (после выхода ps4, xone, но не изжившие свой цикл) на которые стоит обратить внимание, 3ds, psv и wiiu psv - уверенно выпускает новые релизы.
# и отдельная платформа PC, которая демонстрирует постоянство год от года, как по продажам, так и по выпуску новых релизов
#
# Вкусы в Северной Америке и Европе схожи: и там, и там живут фанаты экшнов, спортивных игр, шутеров и смешанного жанра . В Северной Америке больше играют в ролевые игры, в Европе же чаще выбирают гонки.
#
# В Японии вкус совершенно иной - на первом месте ролевые игры, причем с большим отрывом. Далее экшны, смешаного жанра, спортивные игры и в конце платформеры.
# Для рынка Японии стоит присмотреться к играм, не имеющим рейтингов в представленных данных (проверить рейтинги в других системах, распространенных на рынках Японии)
#
# Самое сильное влияние на итоговую выручку оказывают, в большинстве случаев, оценки критиков. Оценки пользователей таким "влиянием" на выручку похвастаться не могут.
#
# Если посмотреть глубже, то рынок компьютерных игр прошел свой взлет, и начинает снижаться активными темпами. Рост продаж достигается при выпуске новых платформ. Стоимость и время создания игр растет. Есть платформы, которые закончили или заканчивают свое развитие, с выходом новых платформ. Имеет смысл внимательно присматриваться к новым платформам, но при этом искать дополнительно платформы, которые имеют стабильную базу пользователей и игр.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# В целом сам проект выполнен на хорошем уровне! На протяжении всей работы чувствуется глубина проработки задачи и это безусловный плюс для нас. Было использовано большое количество методов, которые будут помогать тебе в дальнейших проектах.
#
# Не стоит забывать про оформление своей работы, это важный такой же важный этап. Рекомендую «не стесняться» использовать ячейки типа **markdown** там где нам необходимо отобразить свои размышления, в том числе с использованием дополнительной стилизации.
#
# Успехов тебе в новых проектах!
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Рекомендую посмотреть на дополнительную стилизацию ячеек типа **markdown**.
#
# **Жирный**
# *Курсив*
#
# ---
#
# # Заголовок первого уровня
#
# ---
#
# ## Заголовок второго уровня
#
# ---
# Списки:
#
# - один
# - два
# - три
#
# ---
#
# 1. Раз
# 2. Раз раз
# 3. Раз два три
#
# ---
#
# Отображение `переменных`
#
#
# ---
#
# Также здесь можно найти все, что нужно:
#
# https://www.notion.so/35d9c2f32ffa42f3b17010737aedca4b
#
# </div>
